# %% [markdown]
# <a href="https://colab.research.google.com/github/annisyaaa/ml_sentimen-analysis/blob/main/fiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tweepy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy

# %%
tweepy.__version__
# Out:
# '4.12.1'

# %%
bearer_token = "AAAAAAAAAAAAAAAAAAAAAESWkwEAAAAAf%2BTnoU4KORsW4TSmwERxh5FMUUI%3DUOdTJOSXhvishwPUSPHZajnY78JvhpWbTFA2rrj5EWVEwiobez"
client = tweepy.Client(bearer_token = bearer_token)
client

# %%
dir(client)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_construct_response',
#  '_get_authenticating_user_id',
#  '_get_oauth_1_authenticating_user_id',
#  '_get_oauth_2_authenticating_user_id',
#  '_make_request',
#  '_process_data',
#  '_process_includes',
#  '_process_params',
#  'access_token',
#  'access_token_secret',
#  'add_list_member',
#  'bearer_token',
#  'block',
#  'bookmark',
#  'consumer_key',
#  'consumer_secret',
#  'create_compliance_job',
#  'create_direct_message',
#  'create_direct_message_conversation',
#  'create_dm',
#  'create_dm_conversation',
#  'create_list',
#  'create_tweet',
# ...

# %%
query = "kdrt -is:retweet"

# %%
tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100)
tweets
# Out:
# Response(data=[<Tweet id=1611618649403719683 text='KPAI sorot kasus KDRT Raden Indrajana terhadap anaknya\nhttps://t.co/V2dHLONUFx https://t.co/Hb0kJ5Y4DX'>, <Tweet id=1611617430325055488 text='@neptunegurls ⠀⠀\nWKWKWKWKWKWKWK. KDRT. 😠\n⠀⠀'>, <Tweet id=1611615858840965122 text='@MiddleEastMnt Udah hajji kau marina janda kdrt-(🤣) kasian ya https://t.co/vD78oJjPmX'>, <Tweet id=1611615120337276929 text='@forvita @rubbergameid Wkwkwkwk. Semenjak masalah kdrt suruh diem² langsung males dengerin.'>, <Tweet id=1611612720801140736 text='@tanyakanrl Lebih baik jgn. Krn sudah ada bibit KDRT ke anak bayi'>, <Tweet id=1611611706924597248 text='@einkephalin KDRT!!!!! https://t.co/oPLfvingL0'>, <Tweet id=1611606195680444418 text='@ayemuridteladan knp sy yang dipukul ya ini konsepnya kdrt apa gimana bRo'>, <Tweet id=1611605937269403649 text='@wewekgombell Padahal kan ngent0t harus sama sama mau. Kalau salah sau ga mau ya ga akan terjadi perngent0tan yang ada pemerkosaan. Suami-istri yang sah aja ka
# ...

# %%
for tweet in tweets.data:
    print("Text: ", tweet.text)
    print("Created at: ", tweet.created_at)
    print("\n")
# Out:
# Text:  KPAI sorot kasus KDRT Raden Indrajana terhadap anaknya
# https://t.co/V2dHLONUFx https://t.co/Hb0kJ5Y4DX
# Created at:  2023-01-07 07:00:03+00:00
#
#
# Text:  @neptunegurls ⠀⠀
# WKWKWKWKWKWKWK. KDRT. 😠
# ⠀⠀
# Created at:  2023-01-07 06:55:12+00:00
#
#
# Text:  @MiddleEastMnt Udah hajji kau marina janda kdrt-(🤣) kasian ya https://t.co/vD78oJjPmX
# Created at:  2023-01-07 06:48:57+00:00
#
#
# Text:  @forvita @rubbergameid Wkwkwkwk. Semenjak masalah kdrt suruh diem² langsung males dengerin.
# Created at:  2023-01-07 06:46:01+00:00
#
#
# Text:  @tanyakanrl Lebih baik jgn. Krn sudah ada bibit KDRT ke anak bayi
# Created at:  2023-01-07 06:36:29+00:00
#
#
# Text:  @einkephalin KDRT!!!!! https://t.co/oPLfvingL0
# Created at:  2023-01-07 06:32:27+00:00
#
#
# Text:  @ayemuridteladan knp sy yang dipukul ya ini konsepnya kdrt apa gimana bRo
# Created at:  2023-01-07 06:10:33+00:00
#
#
# ...

# %%
for tweet in tweets.data:
    print(tweet.text)
    if len(tweet.context_annotations) > 0:
        print("\n")
        print(tweet.context_annotations)
# Out:
# KPAI sorot kasus KDRT Raden Indrajana terhadap anaknya
# https://t.co/V2dHLONUFx https://t.co/Hb0kJ5Y4DX
# @neptunegurls ⠀⠀
# WKWKWKWKWKWKWK. KDRT. 😠
# ⠀⠀
# @MiddleEastMnt Udah hajji kau marina janda kdrt-(🤣) kasian ya https://t.co/vD78oJjPmX
# @forvita @rubbergameid Wkwkwkwk. Semenjak masalah kdrt suruh diem² langsung males dengerin.
# @tanyakanrl Lebih baik jgn. Krn sudah ada bibit KDRT ke anak bayi
# @einkephalin KDRT!!!!! https://t.co/oPLfvingL0
#
#
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557696940178935808', 'name': 'Gaming Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to offline and online games such as gaming consoles, tabletop games, video game publishers'}}]
# @ayemuridteladan knp sy yang dipukul ya ini konsepnya kdrt apa gimana bRo
# ...

# %%
import requests

# %%
client1 = tweepy.Client(bearer_token = bearer_token, return_type = requests.Response)
client1

# %%
new_tweets = client1.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100)
new_tweets
# Out:
# <Response [200]>

# %%
tweets_json = new_tweets.json()
tweets_json
# Out:
# {'data': [{'text': 'KPAI sorot kasus KDRT Raden Indrajana terhadap anaknya\nhttps://t.co/V2dHLONUFx https://t.co/Hb0kJ5Y4DX',
#    'id': '1611618649403719683',
#    'edit_history_tweet_ids': ['1611618649403719683'],
#    'created_at': '2023-01-07T07:00:03.000Z'},
#   {'text': '@neptunegurls ⠀⠀\nWKWKWKWKWKWKWK. KDRT. 😠\n⠀⠀',
#    'id': '1611617430325055488',
#    'edit_history_tweet_ids': ['1611617430325055488'],
#    'created_at': '2023-01-07T06:55:12.000Z'},
#   {'text': '@MiddleEastMnt Udah hajji kau marina janda kdrt-(🤣) kasian ya https://t.co/vD78oJjPmX',
#    'id': '1611615858840965122',
#    'edit_history_tweet_ids': ['1611615858840965122'],
#    'created_at': '2023-01-07T06:48:57.000Z'},
#   {'text': '@forvita @rubbergameid Wkwkwkwk. Semenjak masalah kdrt suruh diem² langsung males dengerin.',
#    'id': '1611615120337276929',
#    'edit_history_tweet_ids': ['1611615120337276929'],
#    'created_at': '2023-01-07T06:46:01.000Z'},
# ...

# %%
import pandas as pd
tweets_data = tweets_json['data'] 
df = pd.json_normalize(tweets_data) 
df
# Out:
#                                                  text                   id  \
# 0   KPAI sorot kasus KDRT Raden Indrajana terhadap...  1611618649403719683
# 1       @neptunegurls ⠀⠀\nWKWKWKWKWKWKWK. KDRT. 😠\n⠀⠀  1611617430325055488
# 2   @MiddleEastMnt Udah hajji kau marina janda kdr...  1611615858840965122
# 3   @forvita @rubbergameid Wkwkwkwk. Semenjak masa...  1611615120337276929
# 4   @tanyakanrl Lebih baik jgn. Krn sudah ada bibi...  1611612720801140736
# ..                                                ...                  ...
# 91  Raffi Ahmad KDRT jambak rambut dorong Nagita S...  1611374034918453248
# 92  ️️\nㅤ\n️️\n\n( KDRT hajimaaaa @leaterhy )\n️️\...  1611370663197167619
# 93  5 Tips Menghindari Potensi Terjadinya KDRT, Pe...  1611370266298572801
# 94                                      @convomf KDRT  1611367917039554568
# 95     @coupshanie @treasuremembers jangan kdrt yh 😔😔  1611366993017581568
#
#    edit_history_tweet_ids                created_at  \
# ...

# %%
df['text']
# Out:
# 0     KPAI sorot kasus KDRT Raden Indrajana terhadap...
# 1         @neptunegurls ⠀⠀\nWKWKWKWKWKWKWK. KDRT. 😠\n⠀⠀
# 2     @MiddleEastMnt Udah hajji kau marina janda kdr...
# 3     @forvita @rubbergameid Wkwkwkwk. Semenjak masa...
# 4     @tanyakanrl Lebih baik jgn. Krn sudah ada bibi...
#                             ...
# 91    Raffi Ahmad KDRT jambak rambut dorong Nagita S...
# 92    ️️\nㅤ\n️️\n\n( KDRT hajimaaaa @leaterhy )\n️️\...
# 93    5 Tips Menghindari Potensi Terjadinya KDRT, Pe...
# 94                                        @convomf KDRT
# 95       @coupshanie @treasuremembers jangan kdrt yh 😔😔
# Name: text, Length: 96, dtype: object

# %%
df.to_csv('file_name.csv')
